# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"D:\data_sets\company_revenues.csv")

# %%
data
# Out:
#         company  revenue
# 0         Tesla     31.0
# 1          UBER     11.0
# 2        Amazon    386.0
# 3  Jindal Steel      4.7
# 4     Axis Bank      5.6
# 5       Vedanta     11.3

# %%
data.plot(x = "company" , y = "revenue" , kind = "bar")
# Out:
# <AxesSubplot: xlabel='company'>

# %% [markdown]
# # using the logarithm for the better comparision.

# %%
data.plot(x = "company" , y = "revenue" , kind = "bar" , logy = True)
# Out:
# <AxesSubplot: xlabel='company'>
